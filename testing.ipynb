# %%
import pandas as pd
df = pd.read_csv("PhonePe_Transaction_Statement2.csv")
df.sample(10)
# Out:
#                   Transaction Statement for 8851084852  \
# 186                             May 16, 2022\n12:03 PM
# 111                             Aug 30, 2022\n05:00 PM
# 344  This is an automatically generated statement. ...
# 136                                       Jul 30, 2022
# 12                              Dec 25, 2022\n01:02 PM
# 147                             Jul 05, 2022\n02:13 AM
# 13                                                 NaN
# 189                             May 03, 2022\n07:28 PM
# 306                             Feb 20, 2022\n04:20 PM
# 201                             Apr 28, 2022\n08:55 PM
#
#                                             Unnamed: 1    Unnamed: 2  \
# 186  Paid to Zomato\nTransaction ID : T220516120321...           NaN
# 111  Paid - Mobile Recharge\nTransaction ID : NX220...           NaN
# 344                                                NaN           NaN
# 136                                 Paid to Zomato Ltd           NaN
# 12   Paid to 9311036014\nTransaction ID : T22122513...           NaN
# 147  Paid to amazonupi@apl\nTransaction ID : APL321...           NaN
# 13                                                 NaN  Page 1 of 23
# 189  Paid to ANKIT JAIN\nTransaction ID : T22050319...           NaN
# 306  Paid to Power And Torque LLP\nTransaction ID :...           NaN
# 201  Paid to Zerodha Broking Ltd\nTransaction ID : ...           NaN
#
#     Unnamed: 3   Unnamed: 4
# 186      Debit    INR 270.5
# 111      Debit     INR 15.0
# 344        NaN          NaN
# 136      Debit    INR 369.5
# 12       Debit   INR 3500.0
# 147      Debit    INR 699.0
# 13         NaN          NaN
# 189      Debit     INR 70.0
# 306      Debit  INR 18355.0
# 201      Debit   INR 3000.0

# %%
df.drop(columns=["Unnamed: 2"], inplace=True, errors='ignore')
df.sample(10)
# Out:
#      Transaction Statement for 8851084852  \
# 104                                   NaN
# 235                Apr 13, 2022\n09:46 AM
# 25                 Nov 23, 2022\n04:34 PM
# 347  /privacy-policy/ for Privacy Policy.
# 117                Aug 21, 2022\n01:59 PM
# 113                Aug 27, 2022\n01:17 PM
# 262                Mar 25, 2022\n08:16 PM
# 111                Aug 30, 2022\n05:00 PM
# 264                Mar 25, 2022\n03:44 PM
# 4                                     NaN
#
#                                             Unnamed: 1 Unnamed: 3  Unnamed: 4
# 104  This is a system generated statement. For any ...        NaN         NaN
# 235  Paid to rajesh negi\nTransaction ID : T2204130...      Debit  INR 4000.0
# 25   Paid to JYOTI MEDICOS\nTransaction ID : T22112...      Debit   INR 650.0
# 347                                                NaN        NaN         NaN
# 117  Paid - Mobile Recharge\nTransaction ID : NX220...      Debit    INR 15.0
# 113  Paid to Zomato Ltd\nTransaction ID : T22082713...      Debit  INR 294.75
# 262  Paid to Mohit jain\nTransaction ID : T22032520...      Debit   INR 100.0
# 111  Paid - Mobile Recharge\nTransaction ID : NX220...      Debit    INR 15.0
# 264  Paid to Doms pizza\nTransaction ID : T22032515...      Debit   INR 710.0
# 4                                UTR No : 236530719674        NaN         NaN

# %%
df.rename(columns={"Transaction Statement for 8851084852": "Datetime"}, inplace=True)
df.rename(columns={"Unnamed: 1": "Name"}, inplace=True)
df.rename(columns={"Unnamed: 3": "Type"}, inplace=True)
df.rename(columns={"Unnamed: 4": "Amount"}, inplace=True)
df.sample(10)
# Out:
#                    Datetime  \
# 81   Oct 01, 2022\n01:04 PM
# 124                     NaN
# 240                    Date
# 51   Oct 30, 2022\n10:58 PM
# 73                      NaN
# 319                     NaN
# 309  Feb 20, 2022\n04:16 PM
# 311  Feb 20, 2022\n04:16 PM
# 341                     NaN
# 85   Sep 27, 2022\n06:48 PM
#
#                                                   Name   Type       Amount
# 81   Paid - Mobile Recharge\nTransaction ID : NX221...  Debit    INR 211.0
# 124                                     Paid by XX5810    NaN          NaN
# 240                                Transaction Details    NaN       Amount
# 51   Paid - Mobile Recharge\nTransaction ID : NX221...  Debit     INR 15.0
# 73                                                 NaN    NaN          NaN
# 319                                     Paid by XX5810    NaN          NaN
# 309  Paid to Power And Torque LLP\nTransaction ID :...  Debit  INR 10000.0
# 311  Paid to Power And Torque LLP\nTransaction ID :...  Debit  INR 10000.0
# 341                              UTR No : 201092943443    NaN          NaN
# 85   Paid to ZoFlair Technologies\nTransaction ID :...  Debit    INR 400.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353 entries, 0 to 352
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Datetime  258 non-null    object
#  1   Name      320 non-null    object
#  2   Type      203 non-null    object
#  3   Amount    220 non-null    object
# dtypes: object(4)
# memory usage: 11.2+ KB

# %%
df = df.dropna()
df.sample(10)
# Out:
#                    Datetime  \
# 206  Apr 23, 2022\n12:31 PM
# 265  Mar 25, 2022\n11:41 AM
# 112  Aug 27, 2022\n02:29 PM
# 24   Nov 28, 2022\n01:12 PM
# 159  Jun 22, 2022\n12:56 PM
# 173  May 30, 2022\n07:08 PM
# 177  May 23, 2022\n01:16 PM
# 21   Dec 01, 2022\n05:00 PM
# 20   Dec 17, 2022\n07:19 PM
# 279  Mar 14, 2022\n02:41 PM
#
#                                                   Name   Type      Amount
# 206  Paid to Rastogi jaljira shikanji\nTransaction ...  Debit    INR 20.0
# 265  Paid to Sarvesh veg biryani\nTransaction ID : ...  Debit    INR 50.0
# 112  Paid - Mobile Recharge\nTransaction ID : NX220...  Debit    INR 15.0
# 24   Paid - Mobile Recharge\nTransaction ID : NX221...  Debit   INR 211.0
# 159  Paid to Shivam Prajapati\nTransaction ID : T22...  Debit    INR 30.0
# 173  Paid - Mobile Recharge\nTransaction ID : NX220...  Debit   INR 181.0
# 177  Paid to Zomato\nTransaction ID : T220523131651...  Debit   INR 269.5
# 21   Paid to DEALSKART ONLINE SERVICES PVT LTD\nTra...  Debit    INR 99.0
# 20   Paid to Amazon India\nTransaction ID : APY0185...  Debit   INR 199.0
# 279  Paid to Power And Torque LLP\nTransaction ID :...  Debit  INR 1300.0

# %%
df["Amount"] = df["Amount"].str.replace("INR ", "").astype(float)
df.sample(10)
# Out:
#                    Datetime  \
# 52   Oct 30, 2022\n06:15 PM
# 151            Jul 02, 2022
# 16             Dec 23, 2022
# 86   Sep 25, 2022\n08:05 PM
# 205  Apr 23, 2022\n01:06 PM
# 261  Mar 25, 2022\n08:37 PM
# 76             Oct 19, 2022
# 166            Jun 20, 2022
# 181            May 16, 2022
# 278  Mar 15, 2022\n11:20 AM
#
#                                                   Name   Type   Amount
# 52   Paid to Gaurav Kumar\nTransaction ID : T221030...  Debit  2000.00
# 151                              Paid to amazonupi@apl  Debit   699.00
# 16                        Paid to Jan Sewa Kendar ....  Debit   100.00
# 86   Paid to Pardeep gupta RESTAURANT\nTransaction ...  Debit   500.00
# 205  Paid to ABHISHEK KUMAR\nTransaction ID : T2204...  Debit   150.00
# 261  Paid to Mohit bakery and confectionery\nTransa...  Debit    38.00
# 76                                  Paid to ANKIT JAIN  Debit    24.00
# 166                           Paid to Perfect Computer  Debit   180.00
# 181                                     Paid to Zomato  Debit   178.75
# 278  Paid to Sarvesh veg biryani\nTransaction ID : ...  Debit    60.00

# %%
df.head()
# Out:
#                  Datetime                                               Name  \
# 2            Dec 31, 2022                              Paid to VIPIN CHAUHAN
# 6  Dec 31, 2022\n11:51 AM  Paid to VIPIN CHAUHAN\nTransaction ID : T22123...
# 7  Dec 30, 2022\n04:39 PM  Paid to Gaurav Kumar\nTransaction ID : T221230...
# 8  Dec 30, 2022\n10:33 AM  Paid to Jr MOHD ABUZAR\nTransaction ID : T2212...
# 9  Dec 29, 2022\n11:02 AM  Paid to Gamma Tech Services LLP\nTransaction I...
#
#     Type  Amount
# 2  Debit   300.0
# 6  Debit  1200.0
# 7  Debit   400.0
# 8  Debit    38.0
# 9  Debit  4490.0

# %%
df["Datetime"] = pd.to_datetime(df["Datetime"].str.split("\n").str[0], format="%b %d, %Y")
df.sample(10)
# Out:
#       Datetime                                               Name   Type  \
# 51  2022-10-30  Paid - Mobile Recharge\nTransaction ID : NX221...  Debit
# 261 2022-03-25  Paid to Mohit bakery and confectionery\nTransa...  Debit
# 189 2022-05-03  Paid to ANKIT JAIN\nTransaction ID : T22050319...  Debit
# 146 2022-07-14  Paid - Mobile Recharge\nTransaction ID : NX220...  Debit
# 326 2022-02-06  Paid to gabru\nTransaction ID : T2202061819392...  Debit
# 320 2022-02-19  Paid to Sonu\nTransaction ID : T22021915330881...  Debit
# 232 2022-04-13  Paid to KIRAN PARASHAR\nTransaction ID : T2204...  Debit
# 188 2022-05-05  Paid to gabru\nTransaction ID : T2205050932191...  Debit
# 26  2022-11-23  Paid to Gaurav Kumar\nTransaction ID : T221123...  Debit
# 264 2022-03-25  Paid to Doms pizza\nTransaction ID : T22032515...  Debit
#
#      Amount
# 51     15.0
# 261    38.0
# 189    70.0
# 146   151.0
# 326   100.0
# 320    70.0
# 232    50.0
# 188   110.0
# 26   2000.0
# 264   710.0

# %%
df.sample(10)
# Out:
#       Datetime                                               Name    Type  \
# 266 2022-03-24  Paid to amazonupi@apl\nTransaction ID : APLaa3...   Debit
# 20  2022-12-17  Paid to Amazon India\nTransaction ID : APY0185...   Debit
# 57  2022-10-25  Received from Gaurav Kumar\nTransaction ID : T...  Credit
# 331 2022-01-25                             Paid - Mobile Recharge   Debit
# 2   2022-12-31                              Paid to VIPIN CHAUHAN   Debit
# 140 2022-07-22  Paid to amazonupi@apl\nTransaction ID : APLf31...   Debit
# 132 2022-08-01  Paid to ANKIT JAIN\nTransaction ID : T22080113...   Debit
# 335 2022-01-15                     Paid to V M FOODS AND SERVICES   Debit
# 115 2022-08-22  Paid to Amazon Pay\nTransaction ID : APL06c5fe...   Debit
# 203 2022-04-27  Paid to Radhe Krishana Bangle Store\nTransacti...   Debit
#
#      Amount
# 266   319.0
# 20    199.0
# 57   3500.0
# 331   181.0
# 2     300.0
# 140   309.0
# 132    15.0
# 335    80.0
# 115   389.0
# 203   100.0

# %%
def extract_text(row):
    if row["Type"] == "Credit":
        return row["Name"].split("Received from ")[1].split("\n")[0] if "Received from" in row["Name"] else None
    elif row["Type"] == "Debit":
        if "Paid to" in row["Name"]:
            return row["Name"].split("Paid to ")[1].split("\n")[0]
        elif "Paid -" in row["Name"]:
            return row["Name"].split("Paid - ")[1].split("\n")[0]
        else:
            return None
    else:
        return None

# Apply the function to create a new column
df["Name"] = df.apply(extract_text, axis=1)

# %%
df.sample(10)
# Out:
#       Datetime                   Name   Type  Amount
# 141 2022-07-21             9311036014  Debit  3000.0
# 235 2022-04-13            rajesh negi  Debit  4000.0
# 325 2022-02-06            VISHAL GARG  Debit   100.0
# 67  2022-10-25  Gbru Juliyat Saloon..  Debit    50.0
# 128 2022-08-13         SHUBHAM TANWAR  Debit    60.0
# 102 2022-09-03        Mobile Recharge  Debit   211.0
# 136 2022-07-30             Zomato Ltd  Debit   369.5
# 87  2022-09-23            Vijay hotel  Debit   252.0
# 6   2022-12-31          VIPIN CHAUHAN  Debit  1200.0
# 296 2022-02-26                 ISKATE  Debit  1140.0

# %%
nan_values = df[df.isna().any(axis=1)]

# Print rows with NaN values
print(nan_values)
# Out:
# Empty DataFrame
# Columns: [Datetime, Name, Type, Amount]
# Index: []

# %%
import calendar
df['Year'] = df['Datetime'].dt.year
df['Month'] = df['Datetime'].dt.month
df['Month'] = df['Month'].apply(lambda x: calendar.month_name[int(x)])
df['Date'] = df['Datetime'].dt.day
df['Day_of_Week'] = df['Datetime'].dt.day_name()

# %%
df.sample(10)
# Out:
#       Datetime                               Name    Type   Amount  Year  \
# 147 2022-07-05                      amazonupi@apl   Debit    699.0  2022
# 131 2022-08-05                    Mobile Recharge   Debit    211.0  2022
# 57  2022-10-25                       Gaurav Kumar  Credit   3500.0  2022
# 68  2022-10-22                        Vijay hotel   Debit    150.0  2022
# 246 2022-04-10                              gabru   Debit    100.0  2022
# 144 2022-07-19  Razorpay Software Private Limited   Debit    999.0  2022
# 65  2022-10-25                    Mobile Recharge   Debit     10.0  2022
# 295 2022-02-28                        VISHAL GARG   Debit     41.0  2022
# 308 2022-02-20               Power And Torque LLP   Debit  10000.0  2022
# 26  2022-11-23                       Gaurav Kumar   Debit   2000.0  2022
#
#         Month  Date Day_of_Week
# 147      July     5     Tuesday
# 131    August     5      Friday
# 57    October    25     Tuesday
# 68    October    22    Saturday
# 246     April    10      Sunday
# 144      July    19     Tuesday
# 65    October    25     Tuesday
# 295  February    28      Monday
# 308  February    20      Sunday
# 26   November    23   Wednesday

# %%
df.to_csv('finaldf.csv')

# %% [markdown]
# # Data Analytics

# %%
total_debit = df[df['Type'] == 'Debit']['Amount'].sum()
total_credit = df[df['Type'] == 'Credit']['Amount'].sum()

print(f"Total Debit: {total_debit}")
print(f"Total Credit: {total_credit}")
# Out:
# Total Debit: 196333.32
# Total Credit: 23650.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x=['Debit', 'Credit'], y=[total_debit, total_credit])
plt.xlabel('Transaction Type')
plt.ylabel('Total Amount')
plt.title('Total Debit vs Credit Amount')
plt.show()
# Out:
# c:\Users\Danjin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
transaction_types = df['Type'].value_counts()
plt.pie(transaction_types, labels=transaction_types.index, autopct='%1.1f%%')
plt.title('Pie Chart of Transaction Types')
plt.show()

# %%
df.set_index('Datetime', inplace=True)
df.resample('M')['Amount'].sum().plot(kind='line')
plt.xlabel('Date')
plt.ylabel('Total Amount')
plt.title('Total Amount Transacted Over Time')
plt.show()

# %%
sns.boxplot(x='Type', y='Amount', data=df)
plt.xlabel('Transaction Type')
plt.ylabel('Amount')
plt.title('Boxplot of Transaction Amounts by Type')
plt.show()

# %%
unique_names = df['Name'].unique()
for name in unique_names:
    print(name)
# Out:
# VIPIN CHAUHAN
# Gaurav Kumar
# Jr MOHD ABUZAR
# Gamma Tech Services LLP
# gabru
# Jio Mobility
# 9311036014
# Jan Sewa Kendar ....
# Amazon India
# DEALSKART ONLINE SERVICES PVT LTD
# OM Eye Centre ...
# Mobile Recharge
# JYOTI MEDICOS
# Raj Sharma
# Vijay hotel
# Sunheri lal sweets..
# Dharmendra Saw
# Poonam
# Anas Barber Material
# Gbru Juliyat Saloon..
# TATTOO POINT
# ASIF ANSARI
# ANKIT JAIN
# Piyush
# shubham singh
# Zomato Ltd
# ZoFlair Technologies
# Pardeep gupta RESTAURANT
# Zomato Online Order
# Amazon Pay
# Power And Torque LLP
# Chandan
# Sonu shop
# sonu kumar
# SHUBHAM TANWAR
# amazonupi@apl
# Razorpay Software Private Limited
# Kajal Photo Studio
# Shivam Prajapati
# B
# Krishan Murari Filling St
# Sarvesh veg biryani
# Perfect Computer
# RazorpayZomato
# Anuj chauhan
# Bright Future Way
# Zomato
# Saifi cycle Store
# SWIGGY
# SATISH KUMAR
# Zerodha Broking Ltd
# Instamojo
# Radhe Krishana Bangle Store
# ABHISHEK KUMAR
# Rastogi jaljira shikanji
# MAYANK MITRA
# URMILA DEVI
# MCDONALDS
# WEALTHIAN PRIVATE LIMITED
# Mannat Dhaba
# SONIA THAKUR GIFT SHOP
# Sameer Kumar
# Mr Sameer Kumar
# KIRAN KUMAR
# KIRAN PARASHAR
# LALIT KUMAR S O SH BALAK RAM
# SURENDRA SINGH
# rajesh negi
# Eddie bakers
# anup singh
# Highway punjabi dhaba
# J.K Cosmetics
# New Paul bhojnalya
# Mohit bakery and confectionery
# Mohit jain
# Doms pizza
# Arora Fast Food
# bookmyshow@axisbank
# Sunny Ice Cream
# Ansh momoj corner
# dev sharma
# KLFS HPCL
# Sunil Soyabeen ve Matar pulao
# VISHAL GARG
# ISKATE
# Pooja garments
# Rankit Saxena
# Navab
# Sonu
# SHUBHAM SO PRADEEP KUMAR
# Fantasy Pastry Shop
# instamojo@indus
# V M FOODS AND SERVICES

# %%
vijay_hotel_transactions = df[df['Name'] == 'Vijay hotel']

vijay_hotel_transactions
# Out:
#                    Name   Type  Amount  Year      Month  Date Day_of_Week
# Datetime
# 2022-11-13  Vijay hotel  Debit   420.0  2022   November    13      Sunday
# 2022-11-13  Vijay hotel  Debit   160.0  2022   November    13      Sunday
# 2022-10-22  Vijay hotel  Debit   150.0  2022    October    22    Saturday
# 2022-09-23  Vijay hotel  Debit   252.0  2022  September    23      Friday
# 2022-09-08  Vijay hotel  Debit   165.0  2022  September     8    Thursday
# 2022-09-06  Vijay hotel  Debit   210.0  2022  September     6     Tuesday
# 2022-09-05  Vijay hotel  Debit   182.0  2022  September     5      Monday
# 2022-09-04  Vijay hotel  Debit   195.0  2022  September     4      Sunday
# 2022-09-03  Vijay hotel  Debit   280.0  2022  September     3    Saturday
# 2022-09-02  Vijay hotel  Debit   266.0  2022  September     2      Friday

# %%
if not vijay_hotel_transactions.empty:
    # Plot a graph
    plt.figure(figsize=(10, 6))
    plt.plot(vijay_hotel_transactions.index, vijay_hotel_transactions['Amount'], marker='o')
    plt.xlabel('Date')
    plt.ylabel('Amount')
    plt.title('Transactions at Vijay Hotel')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("No transactions found for Vijay Hotel.")

# %%
# Assuming your DataFrame is named df
# Assuming Amount > 0 represents credit
credit_df = df[df['Amount'] > 0]

# Group by month and sum the credit amounts
monthly_credit = credit_df.groupby('Month')['Amount'].sum().reset_index()

# Find the month with the highest credit
highest_credit_month = monthly_credit.loc[monthly_credit['Amount'].idxmax()]

print("Month with the highest credit:")
print(highest_credit_month)
# Out:
# Month with the highest credit:
# Month     February
# Amount     98423.0
# Name: 3, dtype: object

# %%
import matplotlib.pyplot as plt

# Grouping the data by month and summing the amounts
monthly_data = df.groupby('Month')['Amount'].sum()

# Creating the bar chart with rotated x-axis labels
plt.figure(figsize=(10, 6))
plt.bar(monthly_data.index, monthly_data.values)
plt.xlabel('Month')
plt.ylabel('Total Amount')
plt.title('Total Amount Spent by Month')
plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees
plt.show()

# %%
import matplotlib.pyplot as plt

# Grouping the data by month and summing the amounts
monthly_data = df.groupby('Month')['Amount'].sum()

# Creating a color palette for the bars
colors = plt.cm.tab20c.colors[:len(monthly_data)]

# Creating the bar chart with customizations
plt.figure(figsize=(12, 6))
bars = plt.bar(monthly_data.index, monthly_data.values, color=colors, edgecolor='black')

# Adding grid lines and labels
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xlabel('Month', fontsize=12, fontweight='bold')
plt.ylabel('Total Amount', fontsize=12, fontweight='bold')
plt.title('Total Amount Spent by Month', fontsize=14, fontweight='bold')

# Rotating x-axis labels and setting font style
plt.xticks(rotation=45)
plt.yticks(fontsize=10)

# Adding data labels on top of each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 20, round(yval, 2), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# Filter the DataFrame for credit and debit transactions
credit_transactions = df[df['Type'] == 'Credit']
debit_transactions = df[df['Type'] == 'Debit']

# Find the top 5 credit and debit transactions
top_5_credit = credit_transactions.nlargest(5, 'Amount')['Datetime']
top_5_debit = debit_transactions.nlargest(5, 'Amount')['Datetime']

# Display the table
st.write("Top 5 Credit Transactions:")
st.table(top_5_credit)

st.write("Top 5 Debit Transactions:")
st.table(top_5_debit)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Danjin\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Datetime'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 6
#       3 debit_transactions = df[df['Type'] == 'Debit']
#       5 # Find the top 5 credit and debit transactions
# ----> 6 top_5_credit = credit_transactions.nlargest(5, 'Amount')['Datetime']
#       7 top_5_debit = debit_transactions.nlargest(5, 'Amount')['Datetime']
#       9 # Display the table
#
# File c:\Users\Danjin\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\Danjin\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Datetime'

# %%
# Counting the number of transactions for each type
transaction_types = df['Type'].value_counts()

# Creating the pie chart
plt.figure(figsize=(8, 8))
plt.pie(transaction_types, labels=transaction_types.index, autopct='%1.1f%%', startangle=90)
plt.title('Percentage of Transaction Types')
plt.show()

# %%
# Counting the number of transactions for each type
transaction_types = df['Type'].value_counts()

# Custom color palette
colors = ['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3']

# Creating the pie chart with customizations
plt.figure(figsize=(8, 8))
plt.pie(transaction_types, labels=transaction_types.index, autopct='%1.1f%%', startangle=90,
        colors=colors, shadow=True)
plt.title('Percentage of Transaction Types', pad=20, fontweight='bold', fontsize=16)
# plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
# Out:
# Text(0.5, 1.0, 'Percentage of Transaction Types')

# %%
debit_data = df[df['Type'] == 'Debit']
top_debit_persons = debit_data.groupby('Name')['Amount'].sum().nlargest(5)

# %%
print(top_debit_persons)
# Out:
# Name
# Power And Torque LLP    90953.0
# Gaurav Kumar            19712.0
# Anuj chauhan            16001.0
# 9311036014              10950.0
# Zerodha Broking Ltd      8500.0
# Name: Amount, dtype: float64

# %%
# Grouping the data by date and summing the amounts
daily_data = df.groupby('Date')['Amount'].sum()
# Plotting the line chart with customizations
plt.figure(figsize=(12, 6))
plt.plot(daily_data.index, daily_data.values, marker='o', linestyle='-', color='b')
plt.xlabel('Date', fontsize=12, fontweight='bold')
plt.ylabel('Total Amount', fontsize=12, fontweight='bold')
plt.title('Daily Total Amount Spent', fontsize=14, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
# Out:
# (array([-20000.,      0.,  20000.,  40000.,  60000.,  80000., 100000.]),
#  [Text(0, -20000.0, '−20000'),
#   Text(0, 0.0, '0'),
#   Text(0, 20000.0, '20000'),
#   Text(0, 40000.0, '40000'),
#   Text(0, 60000.0, '60000'),
#   Text(0, 80000.0, '80000'),
#   Text(0, 100000.0, '100000')])

# %%
# Grouping the data by day of week and summing the amounts
day_of_week_data = df.groupby('Day_of_Week')['Amount'].sum()

# Creating the bar chart
plt.figure(figsize=(10, 6))
plt.bar(day_of_week_data.index, day_of_week_data.values)
plt.xlabel('Day of Week')
plt.ylabel('Total Amount')
plt.title('Total Amount Spent by Day of Week')
plt.show()

# %%
day_of_week_data = df.groupby('Day_of_Week')['Amount'].sum()

# Plotting the bar chart with customizations
plt.figure(figsize=(10, 6))
plt.bar(day_of_week_data.index, day_of_week_data.values, color='skyblue', edgecolor='black')
plt.xlabel('Day of Week', fontsize=12, fontweight='bold')
plt.ylabel('Total Amount', fontsize=12, fontweight='bold')
plt.title('Total Amount Spent by Day of Week', fontsize=14, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
# Out:
# (array([     0.,  20000.,  40000.,  60000.,  80000., 100000., 120000.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 20000.0, '20000'),
#   Text(0, 40000.0, '40000'),
#   Text(0, 60000.0, '60000'),
#   Text(0, 80000.0, '80000'),
#   Text(0, 100000.0, '100000'),
#   Text(0, 120000.0, '120000')])

# %%
# Grouping the data by name and summing the amounts
name_data = df.groupby('Name')['Amount'].sum().sort_values(ascending=False)

# Creating the bar chart
plt.figure(figsize=(12, 6))
plt.bar(name_data.index, name_data.values)
plt.xlabel('Name')
plt.ylabel('Total Amount')
plt.title('Total Amount Spent by Name')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Grouping the data by name and summing the amounts
name_data = df.groupby('Name')['Amount'].sum().sort_values(ascending=False).head(10)

# Plotting the bar chart with customizations
plt.figure(figsize=(12, 6))
plt.bar(name_data.index, name_data.values, color='skyblue', edgecolor='black')
plt.xlabel('Name', fontsize=12, fontweight='bold')
plt.ylabel('Total Amount', fontsize=12, fontweight='bold')
plt.title('Total Amount Spent by Name', fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
# Out:
# (array([     0.,  20000.,  40000.,  60000.,  80000., 100000.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 20000.0, '20000'),
#   Text(0, 40000.0, '40000'),
#   Text(0, 60000.0, '60000'),
#   Text(0, 80000.0, '80000'),
#   Text(0, 100000.0, '100000')])

# %%
# Grouping the data by year and summing the amounts
yearly_data = df.groupby('Year')['Amount'].sum()

# Creating the bar chart
plt.figure(figsize=(10, 6))
plt.bar(yearly_data.index, yearly_data.values)
plt.xlabel('Year')
plt.ylabel('Total Amount')
plt.title('Total Amount Spent by Year')
plt.show()
